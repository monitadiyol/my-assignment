# %% [markdown]
# # Find out how many countries are there in the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data=pd.read_excel('Dataset_w6.xlsx')
print(data)
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# 3             1246700.0                         29784.0
# 4                 442.0                           102.0
# ..                  ...                             ...
# 191            912050.0                         31977.0
# 192            330967.0                         95541.0
# 193            527968.0                         28250.0
# 194            752612.0                         17094.0
# 195            390757.0                         16530.0
#
#      GDP per capita (current US$)  Agricultural production index   \
# 0                           623.2                           125.0
# 1                          3984.2                           134.0
# 2                          4154.1                           160.0
# 3                          4714.1                           175.0
# 4                         14764.5                            88.0
# ..                            ...                             ...
# 191                       11068.9                           118.0
# 192                        2067.9                           136.0
# 193                        1106.4                           136.0
# 194                        1311.1                           179.0
# 195                         890.4                            99.0
#
#      International trade: Imports (million US$)
# 0                                        3568.0
# 1                                        4669.0
# 2                                       47091.0
# 3                                        8790.0
# 4                                         491.0
# ..                                          ...
# 191                                     16324.0
# 192                                    174111.0
# 193                                      6861.0
# 194                                      7442.0
# 195                                      5212.0
#
# [196 rows x 7 columns]

# %%
data1=data['country'].count()
print("How many countries are there in the dhttp://localhost:8888/notebooks/Downloads/Untitled11.ipynb?kernel_name=python3#On-the-average-which-region-has-the-hightestataset?")
data1
# Out:
# How many countries are there in the dataset?
# 196

# %% [markdown]
# #  Find out how many countries with respect to the region are available in the dataset

# %%
sns.set(rc = {'figure.figsize':(14,7)})
country_region = sns.countplot(data =data, x = 'Region')
for each in country_region.containers:
    country_region.bar_label(each)
    plt.xticks(rotation=45)

# %% [markdown]
# # On the average which region has the hightest
# a.GDP per capita(current US)

# %%
data.nlargest(1,['GDP per capita (current US$)'])
# Out:
#         country         Region  Surface area (km2)  \
# 104  Luxembourg  WesternEurope              2586.0
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 104                           584.0                      100160.8
#
#      Agricultural production index   \
# 104                            98.0
#
#      International trade: Imports (million US$)
# 104                                     19124.0

# %% [markdown]
# # 𝑏.𝐼𝑛𝑡𝑒𝑟𝑛𝑎𝑡𝑖𝑜𝑛𝑎𝑙𝑡𝑟𝑎𝑑𝑒:𝐼𝑚𝑝𝑜𝑟𝑡𝑠(𝑚𝑖𝑙𝑙𝑖𝑜𝑛𝑈𝑆 )

# %%
data.nlargest(1,['International trade: Imports (million US$)'])
# Out:
#                       country           Region  Surface area (km2)  \
# 187  United States of America  NorthernAmerica           9833517.0
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 187                        324460.0                       56053.8
#
#      Agricultural production index   \
# 187                           111.0
#
#      International trade: Imports (million US$)
# 187                                   2249661.0

# %% [markdown]
# # Find out which region has more consistent with respect to GDP per capita(current US$)

# %%
data3= data.groupby('Region')['GDP per capita (current US$)'].std().sort_values().plot(kind ='bar')
data3
plt.title("SD of GDP per capita (current US$)")

plt.show()
